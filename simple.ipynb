# %%
# Imports 
import numpy as np
from english_words import english_words_set
import gym
from gym import spaces
from utils.exploration.base_exploration_model import BaseExplorationModel
from gym.utils.env_checker import check_env
from collections import deque
from utils.infrastructure.logger import Logger
from utils.infrastructure.schedule_utils import *

from collections import defaultdict
import re

# %%
class WordleSimple(gym.Env): 
    
    def __init__(self,
                 answer: str = None, 
                 valid_words: list = None, 
                 keep_answer_on_reset: bool = False, 
                 logdir: str = 'data'): 
        
        # Store attributes 
        assert(valid_words is not None), 'Must pass valid words'
        self.valid_words = valid_words
        self.n_valid_words = len(self.valid_words)
        self.answer = answer if answer is not None else np.random.choice(self.valid_words)
        self.keep_answer_on_reset = keep_answer_on_reset
        
        # Action + Observation Space
        self.action_space = gym.spaces.Discrete(self.n_valid_words)
        self.observation_space = gym.spaces.Box(low = 0, 
                                                high = 1, 
                                                shape = (self.n_valid_words,), 
                                                dtype = int)

        #  self.observation_space = gym.spaces.MultiDiscrete([2] * self.n_valid_words)
        
        # Init Stuff 
        self.state = np.ones(len(self.valid_words), dtype = int)
        self.guess_count = 0
        self.alphabet = list('abcdefghijklmnopqrstuvwxyz')
        self.possible_words = self.valid_words
        self.n_possible_words = len(self.possible_words)
        self.patterns = ['[abcdefghijklmnopqrstuvwxyz]']*5
        
        # Logging
        self.logging_freq = 500
        self.num_games = 0
        self.victory_buffer = deque(maxlen = self.logging_freq)
        self.win = False
        self.logger = Logger(logdir)   
        
        # Track yellow letters to enforce they are in the word 
        self.all_greens = set()
        self.all_yellows = set()
        self.all_grays = set()
        
    def _create_pattern(self, guess, answer: str = None): 
        
        answer = answer if answer is not None else self.answer
        
        # Init structures to check which letters are green and which are yellow
        greens = dict(zip(range(5), ['']*5))
        yellows = defaultdict(list)
        grays = []

        # Get which words belong where 
        for idx, (guess_letter, answer_letter) in enumerate(zip(guess, answer)): 
            if guess_letter == answer_letter: # green letter
                greens.update({idx: guess_letter})
                self.all_greens.add(guess_letter)
            elif guess_letter in answer: # yellow letter
                yellows[idx].append(guess_letter)
                self.all_yellows.add(guess_letter)
            else: 
                grays.append(guess_letter) # gray letter
                self.all_grays.add(guess_letter)

        # Remove grays from alphabet
        self.alphabet = sorted(set(self.alphabet) - set(grays))

        for i in range(5): 

            if greens[i] != '': 

                # If we have the green letter, we should just replace the whole pattern with this
                self.patterns[i] = '[' + greens[i] + ']'

            elif len(yellows[i])  > 0: 

                # If we get another yellow, remove it from the pattern 
                for letter in yellows[i]: 
                    self.patterns[i] = self.patterns[i].replace(letter, '')

            else: 
                self.patterns[i] = '[' + ''.join(self.alphabet) + ']'


        # Combine patterns into single new pattern 
        pattern = "".join(self.patterns)
        
        return pattern

    def _get_possible_words(self, pattern): 
        
        # Get possible words by matching regex
        new_possible_words = [word for word in self.possible_words if re.match(pattern, word)]

        # Enforce that all yellows are actually in the word -- regex not tracking it necessarily
        yellows = self.all_yellows - self.all_greens
        for letter in yellows: 
            new_possible_words = [word for word in new_possible_words if letter in word]
            
        return new_possible_words
    
    def _compute_reward(self, guess): 
        
        # Create pattern 
        pattern = self._create_pattern(guess)
        
        # Get possible words 
        new_possible_words = self._get_possible_words(pattern)
        print(new_possible_words)

        # Compute reward
        reward = (len(self.possible_words) - len(new_possible_words))/len(self.possible_words)
        
        # Check if won 
        win = bool(guess == self.answer)
        
        # Add win/loss penalty
        if win: 
            reward += 1
        else: 
            reward -= 1
        
        # Add possible word penalty 
        if guess not in self.possible_words: 
            reward -= 1
        

            
        return reward, win, new_possible_words
                
    def step(self, action): 
        
        # Grab decoded word 
        guess = self.valid_words[action]
        
        # Compute reward
        _, win, new_possible_words = self._compute_reward(guess)

        ### TRY GIVING THIS REWARD
        reward = 1 if guess in self.possible_words else -1
        
        # Update state
        self.state = np.array([1 if word in new_possible_words else 0 for word in self.valid_words], dtype=int)
        assert(self.state.shape == self.observation_space.shape), f'{self.state.shape}'
        self.possible_words = new_possible_words
        self.n_possible_words = len(self.possible_words)

        
        # Increment guess count 
        self.guess_count += 1
        
        # Check if done
        done = (win) or (self.guess_count == 6)
        
        # Info 
        info = {'guess_count': self.guess_count, 'won': win}
        
        self.win = win
                
        return self.state, reward, done, info
        
    def reset(self): 

        # Win Ratio logging
        self.victory_buffer.append(self.win)
        self.num_games += 1
        if not self.num_games % self.logging_freq:
            logs = {
                "win ratio": self._compute_win_ratio()
            }
            self.do_logging(logs, self.num_games)
    
       
        # Reset possible words = all valid words
        self.possible_words = self.valid_words
        self.patterns = ['[abcdefghijklmnopqrstuvwxyz]']*5
        self.all_greens = set()
        self.all_yellows = set()
        self.all_grays = set()
        
        # Reset alphabet, state and guess count
        self.alphabet = list('abcdefghijklmnopqrstuvwxyz')
        self.state = np.ones(len(self.valid_words), dtype = int)
        self.guess_count = 0

        # Reset answer 
        if not self.keep_answer_on_reset:
            self.answer = np.random.choice(self.valid_words)
        
        
        return self.state
 
    def _compute_win_ratio(self):
        """
        Computes the win ration of games currently in the victory buffer.
        :return: the win ratio
        """
        wins = sum(self.victory_buffer)
        return wins/len(self.victory_buffer)

    def do_logging(self, logs, num_games):
        """
        :param logs: dictionary containing values to be logged
        :param num_games: the number of games
        :return: logs values to tensorboard
        """
        print(f"Number of Games: {num_games}")
        print(f"State: \n {self.state}")
        print(f"Possible Words: \n {self.possible_words}")
        print(f"Answer: \n {self.answer}")
        for key, value in logs.items():
            print('{} : {}'.format(key, value))
            self.logger.log_scalar(value, key, num_games)
        print("\n")

# %%
words = [word.replace('\n', '').replace(',', '') for word in list(open('scripts/wordle_words.txt', 'r'))]

# %%
env = WordleSimple(valid_words = words, answer = 'roost')
# Out:
# ########################
# logging outputs to  data
# ########################

# %%
env._create_pattern('scoff', 'miser')
# Out:
# '[abcdefghijklmnopqrtuvwxyz][abdeghijklmnpqrstuvwxyz][abdeghijklmnpqrstuvwxyz][abdeghijklmnpqrstuvwxyz][abdeghijklmnpqrstuvwxyz]'

# %%
for i in range(1000): 
    try: 
        obs = env.reset()
        print(f'Answer: {env.answer}\n')
        done = False
        i = 1
        while not done:
            # action, _states = agent.predict(obs)
            action = env.action_space.sample()
            print(f'Guess #{i}: {env.valid_words[action]}')
            obs, rewards, done, info = env.step(action)
            i += 1
    except: 
        print("FUCKED UP")
# Out:
# Answer: scald
#
# Guess #1: brush
# ['aisle', 'ascot', 'aside', 'askew', 'assay', 'asset', 'caste', 'disco', 'easel', 'ensue', 'essay', 'fetus', 'ficus', 'fishy', 'focus', 'islet', 'issue', 'locus', 'mason', 'minus', 'nasal', 'nasty', 'nosey', 'onset', 'pasta', 'paste', 'pasty', 'pesky', 'pesto', 'posit', 'psalm', 'sadly', 'saint', 'salad', 'sally', 'salon', 'salty', 'salve', 'salvo', 'sandy', 'sappy', 'satin', 'savoy', 'savvy', 'scald', 'scale', 'scalp', 'scaly', 'scamp', 'scant', 'scare', 'scarf', 'scary', 'scene', 'scent', 'scion', 'scoff', 'scold', 'scone', 'scoop', 'scope', 'score', 'scorn', 'scout', 'scowl', 'sedan', 'seedy', 'segue', 'seize', 'semen', 'sepia', 'setup', 'seven', 'siege', 'sieve', 'sight', 'sigma', 'silky', 'silly', 'since', 'sinew', 'singe', 'sixty', 'skate', 'skiff', 'skill', 'skimp', 'skirt', 'slack', 'slain', 'slang', 'slant', 'slate', 'sleek', 'sleep', 'sleet', 'slept', 'slice', 'slick', 'slide', 'slime', 'slimy', 'sling', 'slink', 'sloop', 'slope', 'slyly', 'smack', 'small', 'smart', 'smell', 'smelt', 'smile', 'smirk', 'smite', 'smock', 'smoke', 'smoky', 'smote', 'snack', 'snail', 'snake', 'snaky', 'snare', 'snarl', 'sneak', 'snide', 'sniff', 'snipe', 'snoop', 'snore', 'snort', 'snout', 'snowy', 'soapy', 'soggy', 'solid', 'solve', 'sonic', 'sooty', 'space', 'spade', 'spank', 'spare', 'spark', 'spawn', 'speak', 'speck', 'speed', 'spell', 'spelt', 'spend', 'spent', 'sperm', 'spice', 'spicy', 'spied', 'spiel', 'spike', 'spiky', 'spill', 'spilt', 'spine', 'spiny', 'spire', 'spite', 'splat', 'split', 'spoil', 'spoke', 'spoof', 'spook', 'spool', 'spoon', 'spore', 'sport', 'spout', 'stack', 'staff', 'stage', 'staid', 'stain', 'stake', 'stale', 'stalk', 'stall', 'stamp', 'stand', 'stank', 'stare', 'stark', 'start', 'state', 'stave', 'stead', 'steak', 'steal', 'steam', 'steed', 'steel', 'steep', 'stein', 'stern', 'stick', 'stiff', 'still', 'stilt', 'sting', 'stink', 'stint', 'stock', 'stoic', 'stoke', 'stole', 'stomp', 'stone', 'stony', 'stood', 'stool', 'stoop', 'store', 'stork', 'storm', 'story', 'stout', 'stove', 'style', 'swami', 'swamp', 'swarm', 'sweat', 'sweep', 'sweet', 'swell', 'swept', 'swift', 'swill', 'swine', 'swing', 'swirl', 'swoon', 'swoop', 'sword', 'swore', 'sworn', 'synod', 'taste', 'tasty', 'testy', 'visit', 'vista', 'waste', 'wispy', 'zesty']
# Guess #2: serum
# ['sadly', 'saint', 'salad', 'sally', 'salon', 'salty', 'salvo', 'sandy', 'sappy', 'satin', 'savoy', 'savvy', 'scald', 'scalp', 'scaly', 'scant', 'scion', 'scoff', 'scold', 'scoop', 'scowl', 'silky', 'silly', 'sixty', 'skiff', 'skill', 'slack', 'slain', 'slang', 'slant', 'slick', 'sling', 'slink', 'sloop', 'slyly', 'snack', 'snail', 'snaky', 'sniff', 'snoop', 'snowy', 'soapy', 'soggy', 'solid', 'sonic', 'sooty', 'spank', 'spawn', 'spicy', 'spiky', 'spill', 'spilt', 'spiny', 'splat', 'split', 'spoil', 'spoof', 'spook', 'spool', 'spoon', 'stack', 'staff', 'staid', 'stain', 'stalk', 'stall', 'stand', 'stank', 'stick', 'stiff', 'still', 'stilt', 'sting', 'stink', 'stint', 'stock', 'stoic', 'stony', 'stood', 'stool', 'stoop', 'swift', 'swill', 'swing', 'swoon', 'swoop', 'synod']
# Guess #3: saint
# ['scald', 'scalp', 'scaly', 'slack', 'snack', 'snaky', 'soapy', 'stack', 'staff', 'stalk', 'stall']
# Guess #4: agape
# ['scald', 'scaly', 'slack']
# Guess #5: exult
# ['scald', 'scaly']
# Guess #6: itchy
# ['scald']
# Answer: madly
#
# Guess #1: amiss
# ['balmy', 'blame', 'camel', 'cameo', 'champ', 'charm', 'clamp', 'comma', 'cramp', 'cream', 'datum', 'dogma', 'drama', 'dream', 'enema', 'flame', 'foamy', 'frame', 'gamer', 'gamma', 'gamut', 'gleam', 'harem', 'human', 'karma', 'llama', 'loamy', 'macaw', 'macho', 'macro', 'madam', 'madly', 'magma', 'major', 'maker', 'mambo', 'mamma', 'mammy', 'manga', 'mange', 'mango', 'mangy', 'manly', 'manor', 'maple', 'march', 'marry', 'match', 'matey', 'mauve', 'maybe', 'mayor', 'mealy', 'meant', 'meaty', 'mecca', 'medal', 'metal', 'mocha', 'modal', 'molar', 'moral', 'mural', 'nomad', 'psalm', 'qualm', 'ramen', 'realm', 'rearm', 'rumba', 'scamp', 'scram', 'shame', 'sigma', 'stamp', 'steam', 'sumac', 'swamp', 'swarm', 'tamer', 'tramp', 'woman']
# Guess #2: tibia
# ['camel', 'cameo', 'champ', 'charm', 'clamp', 'cramp', 'cream', 'dream', 'flame', 'foamy', 'frame', 'gamer', 'gamut', 'gleam', 'harem', 'human', 'loamy', 'macaw', 'macho', 'macro', 'madam', 'madly', 'major', 'maker', 'mammy', 'mange', 'mango', 'mangy', 'manly', 'manor', 'maple', 'march', 'marry', 'mauve', 'mayor', 'mealy', 'meant', 'medal', 'modal', 'molar', 'moral', 'mural', 'nomad', 'qualm', 'ramen', 'realm', 'rearm', 'woman']
# Guess #3: pasta
# ['camel', 'cameo', 'gamer', 'gamut', 'harem', 'macaw', 'macho', 'macro', 'madam', 'madly', 'major', 'maker', 'mammy', 'mange', 'mango', 'mangy', 'manly', 'manor', 'march', 'marry', 'mauve', 'mayor', 'ramen']
# Guess #4: stoop
# ['camel', 'gamer', 'harem', 'macaw', 'madam', 'madly', 'maker', 'mammy', 'mange', 'mangy', 'manly', 'march', 'marry', 'mauve', 'ramen']
# Guess #5: thigh
# ['camel', 'macaw', 'madam', 'madly', 'maker', 'mammy', 'manly', 'marry', 'mauve', 'ramen']
# Guess #6: plain
# ['camel', 'madly', 'manly']
# Answer: quake
#
# Guess #1: plank
# ['awake', 'brake', 'drake', 'khaki', 'quake', 'shake', 'shaky', 'skate', 'stake']
# Guess #2: dirty
# ['awake', 'quake', 'shake']
# Guess #3: heavy
# ['awake', 'quake', 'shake']
# Guess #4: inlet
# ['awake', 'quake']
# Guess #5: model
# ['awake', 'quake']
# Guess #6: squat
# ['quake']
# Answer: paler
#
# Guess #1: fetus
# ['abbey', 'abide', 'abled', 'abode', 'above', 'adage', 'adobe', 'adore', 'afire', 'agape', 'agile', 'agree', 'ahead', 'aider', 'algae', 'alien', 'alike', 'alive', 'alley', 'alone', 'amaze', 'amber', 'amble', 'amend', 'ample', 'angel', 'anger', 'angle', 'anime', 'ankle', 'annex', 'anode', 'apnea', 'apple', 'arena', 'ashen', 'aside', 'askew', 'atone', 'awake', 'aware', 'awoke', 'badge', 'bagel', 'baker', 'baler', 'barge', 'bible', 'bicep', 'bilge', 'binge', 'biome', 'blade', 'blame', 'blare', 'blaze', 'bleak', 'bleed', 'bleep', 'blend', 'bloke', 'boney', 'booze', 'borne', 'bowel', 'boxer', 'brace', 'brake', 'brave', 'bread', 'break', 'breed', 'bribe', 'bride', 'brine', 'broke', 'budge', 'bugle', 'bulge', 'buyer', 'cable', 'cache', 'cagey', 'camel', 'cameo', 'canoe', 'caper', 'carve', 'cheap', 'check', 'cheek', 'cheer', 'chide', 'chime', 'choke', 'chore', 'cider', 'clean', 'clear', 'clerk', 'clone', 'clove', 'corer', 'coven', 'cover', 'covey', 'cower', 'crane', 'crave', 'craze', 'creak', 'cream', 'credo', 'creed', 'creek', 'creep', 'creme', 'crepe', 'cried', 'crier', 'crime', 'crone', 'curve', 'cyber', 'cycle', 'dance', 'dicey', 'diner', 'diode', 'dirge', 'diver', 'dodge', 'dopey', 'dowel', 'dozen', 'drake', 'drape', 'dread', 'dream', 'dried', 'drier', 'drive', 'drone', 'drove', 'dryer', 'dunce', 'dwell', 'eager', 'eagle', 'early', 'ebony', 'eking', 'elbow', 'elder', 'elegy', 'elide', 'elope', 'email', 'embed', 'ember', 'emcee', 'endow', 'enema', 'enemy', 'enjoy', 'envoy', 'epoch', 'epoxy', 'erode', 'error', 'ether', 'ethic', 'evade', 'every', 'evoke', 'excel', 'exile', 'expel', 'eying', 'gamer', 'gavel', 'gayer', 'gazer', 'given', 'giver', 'glade', 'glare', 'glaze', 'gleam', 'glean', 'glide', 'globe', 'glove', 'gnome', 'golem', 'goner', 'gooey', 'gorge', 'grace', 'grade', 'grape', 'grave', 'graze', 'greed', 'green', 'grime', 'gripe', 'grope', 'grove', 'guide', 'guile', 'halve', 'harem', 'haven', 'hazel', 'hinge', 'homer', 'honey', 'horde', 'hovel', 'hover', 'hyena', 'hymen', 'hyper', 'ideal', 'idler', 'image', 'impel', 'inane', 'index', 'inner', 'joker', 'judge', 'juice', 'knave', 'knead', 'kneed', 'kneel', 'label', 'laden', 'ladle', 'lager', 'lance', 'lapel', 'large', 'layer', 'libel', 'liege', 'liken', 'linen', 'liner', 'liver', 'lodge', 'lover', 'lower', 'lumen', 'lunge', 'maize', 'maker', 'mange', 'maple', 'maybe', 'midge', 'mince', 'miner', 'model', 'modem', 'money', 'mover', 'movie', 'mower', 'naive', 'navel', 'nicer', 'niche', 'niece', 'noble', 'novel', 'nudge', 'oaken', 'ocean', 'odder', 'olden', 'older', 'olive', 'ombre', 'omega', 'opera', 'opine', 'order', 'other', 'ounce', 'ovine', 'owner', 'oxide', 'ozone', 'paler', 'panel', 'paper', 'parer', 'payee', 'payer', 'phone', 'piece', 'piney', 'piper', 'pixel', 'pixie', 'place', 'plane', 'plead', 'plied', 'plier', 'poker', 'power', 'preen', 'price', 'pride', 'pried', 'prime', 'prize', 'probe', 'prone', 'prove', 'puree', 'purer', 'purge', 'quake', 'queen', 'queer', 'quell', 'query', 'racer', 'ramen', 'range', 'rarer', 'raven', 'rhyme', 'rider', 'ridge', 'ripen', 'riper', 'river', 'rodeo', 'roger', 'rover', 'rower', 'ruder', 'ruler', 'rupee', 'valve', 'video', 'viper', 'vixen', 'voice', 'vowel', 'wager', 'waive', 'waver', 'waxen', 'whale', 'wheel', 'whelp', 'where', 'while', 'whine', 'whole', 'widen', 'wider', 'wield', 'wince', 'woken', 'women', 'wooer', 'woven', 'wreak', 'wreck', 'yield']
# Guess #2: mason
# ['badge', 'bagel', 'baker', 'baler', 'barge', 'cable', 'cache', 'cagey', 'caper', 'carve', 'eager', 'eagle', 'early', 'gavel', 'gayer', 'gazer', 'halve', 'hazel', 'label', 'ladle', 'lager', 'lapel', 'large', 'layer', 'paler', 'paper', 'parer', 'payee', 'payer', 'racer', 'rarer', 'valve', 'wager', 'waive', 'waver']
# Guess #3: puppy
# ['paler', 'parer', 'payee', 'payer']
# Guess #4: ethos
# ['paler', 'parer']
# Guess #5: court
# ['paler', 'parer']
# Guess #6: eager
# ['paler', 'parer']
# Answer: swami
#
# Guess #1: stark
# ['scald', 'scale', 'scalp', 'scaly', 'scamp', 'shade', 'shady', 'shale', 'shall', 'shame', 'shape', 'shave', 'shawl', 'slain', 'slang', 'slash', 'small', 'smash', 'snail', 'soapy', 'space', 'spade', 'spasm', 'spawn', 'suave', 'swami', 'swamp', 'swash']
# Guess #2: racer
# ['scald', 'scalp', 'scaly', 'scamp', 'shady', 'shall', 'shawl', 'slain', 'slang', 'slash', 'small', 'smash', 'snail', 'soapy', 'spasm', 'spawn', 'swami', 'swamp', 'swash']
# Guess #3: green
# ['shady', 'shall', 'shawl', 'slash', 'small', 'smash', 'soapy', 'spasm', 'swami', 'swamp', 'swash']
# Guess #4: ledge
# ['smash', 'soapy', 'spasm', 'swami', 'swamp', 'swash']
# Guess #5: clasp
# ['soapy', 'swami']
# Guess #6: skimp
# ['swami']
# Answer: tibia
#
# Guess #1: untie
# ['admit', 'await', 'digit', 'droit', 'fruit', 'habit', 'limit', 'orbit', 'plait', 'posit', 'split', 'staid', 'stair', 'stoic', 'strip', 'tacit', 'tapir', 'their', 'tibia', 'timid', 'tonic', 'topic', 'toxic', 'trail', 'trait', 'visit', 'vomit']
# Guess #2: itchy
# ['admit', 'await', 'digit', 'droit', 'habit', 'limit', 'orbit', 'plait', 'posit', 'split', 'tapir', 'tibia', 'timid', 'trail', 'trait', 'visit', 'vomit']
# Guess #3: baler
# ['tibia']
# Guess #4: harry
# ['tibia']
# Guess #5: chord
# ['tibia']
# Guess #6: inlet
# ['tibia']
# Answer: rajah
#
# Guess #1: decay
# ['altar', 'avian', 'axial', 'banal', 'basal', 'bloat', 'borax', 'briar', 'fatal', 'final', 'float', 'friar', 'gloat', 'groan', 'human', 'lunar', 'molar', 'moral', 'mural', 'nasal', 'natal', 'naval', 'offal', 'organ', 'pagan', 'papal', 'polar', 'rajah', 'rival', 'rural', 'shoal', 'solar', 'sonar', 'splat', 'squat', 'strap', 'straw', 'sugar', 'titan', 'tonal', 'topaz', 'total', 'trial', 'tubal', 'urban', 'usual', 'viral', 'vital', 'woman', 'zonal']
# Guess #2: chaff
# ['human', 'rajah']
# Guess #3: pixie
# ['human', 'rajah']
# Guess #4: fjord
# ['rajah']
# Guess #5: rally
# ['rajah']
# Guess #6: slyly
# ['rajah']
# Answer: store
#
# Guess #1: fugue
# ['abase', 'abate', 'abide', 'abode', 'above', 'adobe', 'adore', 'aisle', 'alike', 'alive', 'alone', 'amaze', 'amble', 'ample', 'anime', 'ankle', 'anode', 'apple', 'arise', 'arose', 'aside', 'atone', 'awake', 'aware', 'awoke', 'baste', 'bathe', 'belie', 'belle', 'bible', 'biome', 'blade', 'blame', 'blare', 'blaze', 'bloke', 'booze', 'borne', 'brace', 'brake', 'brave', 'bribe', 'bride', 'brine', 'broke', 'cable', 'cache', 'canoe', 'carve', 'caste', 'cease', 'chase', 'chide', 'chime', 'choke', 'chore', 'chose', 'clone', 'close', 'clove', 'copse', 'crane', 'crate', 'crave', 'craze', 'creme', 'crepe', 'crime', 'crone', 'cycle', 'dance', 'delve', 'dense', 'diode', 'drake', 'drape', 'drive', 'drone', 'drove', 'eerie', 'elate', 'elide', 'elite', 'elope', 'emcee', 'erase', 'erode', 'evade', 'evoke', 'exile', 'halve', 'haste', 'heave', 'hence', 'horde', 'horse', 'inane', 'irate', 'knave', 'ladle', 'lance', 'lapse', 'lathe', 'latte', 'lease', 'leave', 'lithe', 'loose', 'maize', 'maple', 'masse', 'maybe', 'melee', 'mince', 'moose', 'movie', 'naive', 'nerve', 'niche', 'niece', 'noble', 'noise', 'noose', 'obese', 'olive', 'ombre', 'opine', 'ovate', 'ovine', 'oxide', 'ozone', 'parse', 'paste', 'payee', 'peace', 'pence', 'penne', 'phase', 'phone', 'piece', 'pixie', 'place', 'plane', 'plate', 'poise', 'posse', 'price', 'pride', 'prime', 'prize', 'probe', 'prone', 'prose', 'prove', 'raise', 'rhyme', 'rinse', 'salve', 'scale', 'scare', 'scene', 'scone', 'scope', 'score', 'scree', 'seize', 'sense', 'serve', 'shade', 'shake', 'shale', 'shame', 'shape', 'share', 'shave', 'shine', 'shire', 'shone', 'shore', 'shove', 'sieve', 'since', 'skate', 'slate', 'slice', 'slide', 'slime', 'slope', 'smile', 'smite', 'smoke', 'smote', 'snake', 'snare', 'snide', 'snipe', 'snore', 'solve', 'space', 'spade', 'spare', 'spice', 'spike', 'spine', 'spire', 'spite', 'spoke', 'spore', 'spree', 'stake', 'stale', 'stare', 'state', 'stave', 'stoke', 'stole', 'stone', 'store', 'stove', 'style', 'swine', 'swore', 'table', 'taste', 'tease', 'tense', 'tepee', 'terse', 'theme', 'there', 'these', 'those', 'three', 'thyme', 'tilde', 'tithe', 'title', 'trace', 'trade', 'tribe', 'trice', 'tripe', 'trite', 'trope', 'trove', 'twice', 'twine', 'valve', 'verse', 'verve', 'voice', 'waive', 'waste', 'weave', 'whale', 'where', 'while', 'whine', 'white', 'whole', 'whose', 'wince', 'worse', 'write', 'wrote']
# Guess #2: denim
# ['abase', 'abate', 'above', 'adobe', 'adore', 'aisle', 'amaze', 'amble', 'ample', 'ankle', 'apple', 'arose', 'awake', 'aware', 'awoke', 'baste', 'bathe', 'bible', 'blare', 'blaze', 'bloke', 'booze', 'brace', 'brake', 'brave', 'broke', 'cable', 'cache', 'carve', 'caste', 'chase', 'choke', 'chore', 'chose', 'close', 'clove', 'copse', 'crate', 'crave', 'craze', 'crepe', 'cycle', 'elate', 'elope', 'emcee', 'erase', 'evoke', 'halve', 'haste', 'horse', 'knave', 'lapse', 'lathe', 'latte', 'lithe', 'loose', 'obese', 'ombre', 'ovate', 'parse', 'paste', 'payee', 'phase', 'piece', 'place', 'plate', 'posse', 'probe', 'prose', 'prove', 'salve', 'scale', 'scare', 'scope', 'score', 'scree', 'shake', 'shale', 'shape', 'share', 'shave', 'shore', 'shove', 'sieve', 'skate', 'slate', 'slope', 'smoke', 'smote', 'snake', 'snare', 'snore', 'solve', 'space', 'spare', 'spoke', 'spore', 'spree', 'stake', 'stale', 'stare', 'state', 'stave', 'stoke', 'stole', 'store', 'stove', 'style', 'swore', 'table', 'taste', 'there', 'these', 'those', 'three', 'tithe', 'title', 'trace', 'trope', 'trove', 'valve', 'waste', 'whale', 'where', 'whole', 'whose', 'worse', 'wrote']
# Guess #3: lodge
# ['above', 'adobe', 'adore', 'arose', 'awoke', 'bloke', 'broke', 'choke', 'chore', 'chose', 'close', 'clove', 'elope', 'evoke', 'obese', 'ombre', 'ovate', 'probe', 'prose', 'prove', 'scope', 'score', 'shore', 'shove', 'slope', 'smoke', 'smote', 'snore', 'spoke', 'spore', 'stoke', 'store', 'stove', 'swore', 'those', 'trope', 'trove', 'whose', 'wrote']
# Guess #4: login
# ['above', 'adobe', 'adore', 'arose', 'awoke', 'bloke', 'broke', 'choke', 'chore', 'chose', 'close', 'clove', 'elope', 'evoke', 'obese', 'ombre', 'ovate', 'probe', 'prose', 'prove', 'scope', 'score', 'shore', 'shove', 'slope', 'smoke', 'smote', 'snore', 'spoke', 'spore', 'stoke', 'store', 'stove', 'swore', 'those', 'trope', 'trove', 'whose', 'wrote']
# Guess #5: morph
# ['adore', 'arose', 'broke', 'chore', 'ombre', 'score', 'shore', 'snore', 'spore', 'store', 'swore', 'trove', 'wrote']
# Guess #6: cycle
# ['arose', 'broke', 'store', 'swore', 'trove', 'wrote']
# Answer: print
#
# Guess #1: macho
# ['beefy', 'befit', 'beget', 'begin', 'begun', 'being', 'belie', 'belle', 'belly', 'beret', 'berry', 'beset', 'betel', 'bevel', 'bezel', 'bible', 'biddy', 'bilge', 'billy', 'binge', 'bitty', 'bleed', 'bleep', 'blend', 'bless', 'blind', 'blink', 'bliss', 'blitz', 'bluer', 'bluff', 'blunt', 'blurb', 'blurt', 'breed', 'bribe', 'bride', 'brief', 'brine', 'bring', 'brink', 'briny', 'brisk', 'brunt', 'brute', 'buddy', 'budge', 'buggy', 'bugle', 'build', 'built', 'bulge', 'bulky', 'bully', 'bunny', 'burly', 'burnt', 'burst', 'bused', 'butte', 'buyer', 'debit', 'debug', 'debut', 'defer', 'deign', 'deity', 'delve', 'dense', 'derby', 'deter', 'devil', 'digit', 'dilly', 'diner', 'dingy', 'dirge', 'dirty', 'ditty', 'diver', 'dizzy', 'dress', 'dried', 'drier', 'drift', 'drill', 'drink', 'drive', 'druid', 'drunk', 'dryer', 'dryly', 'dully', 'dusky', 'dusty', 'duvet', 'dwell', 'dwelt', 'dying', 'edify', 'eerie', 'egret', 'eking', 'elder', 'elegy', 'elfin', 'elide', 'elite', 'elude', 'ennui', 'ensue', 'enter', 'entry', 'equip', 'erupt', 'ester', 'etude', 'event', 'every', 'exert', 'exile', 'exist', 'expel', 'exult', 'eying', 'feign', 'ferry', 'fetid', 'fetus', 'fever', 'fewer', 'fiber', 'field', 'fiend', 'fiery', 'fifty', 'filer', 'filet', 'filly', 'finer', 'first', 'fixer', 'fizzy', 'fleet', 'flier', 'fling', 'flint', 'flirt', 'fluff', 'fluid', 'fluke', 'flung', 'flunk', 'flute', 'flyer', 'freed', 'freer', 'fried', 'frill', 'frisk', 'fritz', 'fruit', 'fudge', 'fugue', 'fully', 'fungi', 'funky', 'funny', 'furry', 'fussy', 'fuzzy', 'geeky', 'geese', 'genie', 'genre', 'giddy', 'gipsy', 'girly', 'given', 'giver', 'glide', 'glint', 'greed', 'green', 'greet', 'grief', 'grill', 'grind', 'gripe', 'gruel', 'gruff', 'grunt', 'guess', 'guest', 'guide', 'guild', 'guile', 'guilt', 'guise', 'gully', 'guppy', 'gusty', 'gypsy', 'idler', 'idyll', 'index', 'inept', 'inert', 'infer', 'inlet', 'inner', 'input', 'inter', 'islet', 'issue', 'jelly', 'jerky', 'jetty', 'jewel', 'jiffy', 'judge', 'kinky', 'kitty', 'kneed', 'kneel', 'knelt', 'knife', 'krill', 'ledge', 'leery', 'lefty', 'leggy', 'leper', 'level', 'lever', 'libel', 'liege', 'liken', 'linen', 'liner', 'lipid', 'liver', 'livid', 'lunge', 'lupus', 'lurid', 'lusty', 'lying', 'needy', 'nerdy', 'nerve', 'never', 'newer', 'newly', 'ninny', 'nudge', 'nurse', 'nutty', 'penne', 'penny', 'peril', 'perky', 'pesky', 'petty', 'piety', 'piggy', 'piney', 'pinky', 'piper', 'pique', 'pixel', 'pixie', 'plied', 'plier', 'plunk', 'preen', 'press', 'pride', 'pried', 'print', 'privy', 'prize', 'prude', 'prune', 'pudgy', 'puffy', 'pulpy', 'pulse', 'pupil', 'puppy', 'puree', 'purer', 'purge', 'purse', 'putty', 'queen', 'queer', 'quell', 'query', 'quest', 'queue', 'quiet', 'quill', 'quilt', 'quirk', 'quite', 'rebel', 'rebus', 'rebut', 'reedy', 'refer', 'refit', 'reign', 'renew', 'repel', 'reply', 'rerun', 'reset', 'resin', 'retry', 'reuse', 'revel', 'revue', 'rider', 'ridge', 'rifle', 'rigid', 'rinse', 'ripen', 'riper', 'risen', 'riser', 'risky', 'river', 'rivet', 'ruddy', 'ruder', 'rugby', 'ruler', 'rupee', 'rusty', 'seedy', 'segue', 'seize', 'sense', 'serif', 'serve', 'setup', 'seven', 'sever', 'sewer', 'siege', 'sieve', 'silky', 'silly', 'sinew', 'singe', 'siren', 'sissy', 'sixty', 'skier', 'skiff', 'skill', 'skirt', 'skulk', 'skull', 'skunk', 'sleek', 'sleep', 'sleet', 'slept', 'slide', 'sling', 'slink', 'slung', 'slunk', 'slurp', 'slyly', 'sneer', 'snide', 'sniff', 'snipe', 'snuff', 'speed', 'spell', 'spelt', 'spend', 'spent', 'spied', 'spiel', 'spike', 'spiky', 'spill', 'spilt', 'spine', 'spiny', 'spire', 'spite', 'split', 'spree', 'sprig', 'spunk', 'spurn', 'spurt', 'squib', 'steed', 'steel', 'steep', 'steer', 'stein', 'stern', 'stiff', 'still', 'stilt', 'sting', 'stink', 'stint', 'strip', 'strut', 'study', 'stuff', 'stung', 'stunk', 'stunt', 'style', 'suing', 'suite', 'sulky', 'sully', 'sunny', 'super', 'surer', 'surge', 'surly', 'sweep', 'sweet', 'swell', 'swept', 'swift', 'swill', 'swine', 'swing', 'swirl', 'swung', 'sy ...
# Guess #2: lupus
# ['equip', 'erupt', 'gripe', 'inept', 'penne', 'penny', 'perky', 'pesky', 'petty', 'piety', 'piggy', 'piney', 'pinky', 'pixie', 'preen', 'pride', 'pried', 'print', 'privy', 'prize', 'prude', 'prune', 'tripe', 'wispy']
# Guess #3: tally
# ['inept', 'print']
# Guess #4: viola
# ['inept', 'print']
# Guess #5: cavil
# ['inept', 'print']
# Guess #6: prone
# ['print']
# Answer: taboo
#
# Guess #1: lunch
', 'party', 'pasta', 'paste', 'pasty', 'patio', 'patsy', 'patty', 'payee', 'payer', 'perky', 'pesky', 'pesto', 'petty', 'piety', 'piggy', 'piper', 'pivot', 'pixie', 'pizza', 'podgy', 'poesy', 'poise', 'poker', 'poppy', 'poser', 'posit', 'posse', 'power', 'press', 'pride', 'pried', 'prime', 'primo', 'prior', 'prism', 'privy', 'prize', 'probe', 'proof', 'prose', 'prove', 'proxy', 'pygmy', 'rabbi', 'rabid', 'radar', 'radii', 'radio', 'raise', 'rapid', 'rarer', 'raspy', 'ratio', 'ratty', 'razor', 'ready', 'rearm', 'rebar', 'reedy', 'refer', 'refit', 'remit', 'repay', 'reset', 'retro', 'retry', 'rider', 'ridge', 'rigid', 'rigor', 'riper', 'riser', 'risky', 'river', 'rivet', 'roast', 'robot', 'rodeo', 'roger', 'roomy', 'roost', 'rotor', 'rover', 'rowdy', 'rower', 'safer', 'sappy', 'sassy', 'satyr', 'savor', 'savoy', 'savvy', 'seedy', 'seize', 'sepia', 'serif', 'serve', 'sever', 'sewer', 'siege', 'sieve', 'sigma', 'sissy', 'sixty', 'skate', 'skier', 'skiff', 'skimp', 'skirt', 'smart', 'smear', 'smirk', 'smite', 'smoke', 'smoky', 'smote', 'soapy', 'sober', 'soggy', 'sooty', 'sorry', 'sower', 'spade', 'spare', 'spark', 'spasm', 'speak', 'spear', 'speed', 'sperm', 'sp ...
# Guess #2: ozone
# ['abbot', 'aorta', 'arbor', 'ardor', 'armor', 'arrow', 'axiom', 'bigot', 'board', 'boast', 'bobby', 'borax', 'bosom', 'bossy', 'bravo', 'ditto', 'dodgy', 'dogma', 'dowdy', 'dowry', 'error', 'favor', 'foamy', 'foggy', 'foist', 'foray', 'forgo', 'forty', 'idiom', 'idiot', 'joist', 'major', 'mambo', 'mayor', 'moist', 'mossy', 'motif', 'motor', 'motto', 'patio', 'pivot', 'podgy', 'poesy', 'poppy', 'posit', 'primo', 'prior', 'radio', 'ratio', 'razor', 'rigor', 'roast', 'robot', 'rotor', 'rowdy', 'savor', 'savoy', 'soapy', 'soggy', 'sorry', 'taboo', 'tarot', 'toast', 'today', 'toddy', 'torso', 'vapor', 'vigor', 'visor', 'vodka', 'vomit', 'widow', 'wordy', 'worry', 'worst']
# Guess #3: inter
# ['abbot', 'aorta', 'boast', 'foist', 'forty', 'joist', 'moist', 'taboo', 'tarot', 'toast', 'today', 'toddy', 'torso', 'worst']
# Guess #4: lorry
# ['abbot', 'taboo']
# Guess #5: party
# ['taboo']
# Guess #6: coupe
# ['taboo']
# Answer: dodge
#
# Guess #1: beech
# ['abase', 'abate', 'abbey', 'abide', 'abled', 'abode', 'above', 'abuse', 'acute', 'adage', 'adore', 'afire', 'after', 'agape', 'agate', 'agile', 'agree', 'aider', 'aisle', 'algae', 'alien', 'alike', 'alive', 'alley', 'alone', 'alter', 'amaze', 'amber', 'amble', 'ample', 'amuse', 'angel', 'anger', 'angle', 'anime', 'ankle', 'annex', 'anode', 'apnea', 'apple', 'arg
ivet', 'rodeo', 'roger', 'rogue', 'rouge', 'rouse', 'route', 'rover', 'rower', 'ruder', 'ruler', 'rupee', 'safer', 'salve', 'saner', 'saute', 'scale', 'scare', 'scone', 'scope', 'score', 'scree', 'screw', 'shade', 'shake', 'shale', 'shame', 'shape', 'share', 'shave', 'shied', 'shine', 'shire', 'shone', 'shore', 'shove', 'shrew', 'sinew', 'singe', 'siren', 'skate', 'skier', 'slate', 'slide', 'slime', 'slope', 'smile', 'smite', 'smoke', 'smote', 'snake', 'snare', 'snide', 'snipe', 'snore', 'sober', 'solve', 'sower', 'spade', 'spare', 'spied', 'spiel', 'spike', 'spine', 'spire', 'spite', 'spoke', 'spore', 'spree', 'stage', 'stake', 'stale', 'stare', 'state', 'stave', 'stoke', 'stole', 'stone', 'store', 'stove', 'style', 'suave', 'suite', 'super', 'surer', 'surge', 'swine', 'swore', 'table', 'taken', 'taker', 'tamer', 'taper', 'taste', 'thief', 'those', 'three', 'threw', 'thyme', 'tiger', 'tilde', 'timer', 'title', 'token', 'totem', 'towel', 'tower', 'trade', 'tried', 'tripe', 'trite', 'trope', 'tr ...
# Guess #2: since
# ['adage', 'adore', 'agape', 'agate', 'agree', 'algae', 'amaze', 'ample', 'apple', 'argue', 'awake', 'aware', 'awoke', 'azure', 'dodge', 'drake', 'drape', 'drove', 'eagle', 'elate', 'elope', 'elude', 'erode', 'etude', 'evade', 'evoke', 'flake', 'flame', 'flare', 'fluke', 'flume', 'flute', 'forge', 'forte', 'frame', 'froze', 'fudge', 'fugue', 'gaffe', 'gauge', 'gauze', 'glade', 'glare', 'glaze', 'glove', 'gorge', 'gouge', 'grade', 'grape', 'grate', 'grave', 'graze', 'grope', 'grove', 'judge', 'ladle', 'large', 'latte', 'lodge', 'maple', 'mauve', 'ovate', 'payee', 'plate', 'plume', 'prove', 'prude', 'puree', 'purge', 'quake', 'quote', 'rogue', 'rouge', 'route', 'rupee', 'trade', 'trope', 'trove', 'tulle', 'vague', 'value', 'valve', 'vogue', 'wrote']
# Guess #3: forth
# ['dodge', 'gouge', 'lodge', 'vogue']
# Guess #4: minus
# ['dodge', 'lodge']
# Guess #5: wince
# ['dodge', 'lodge']
# Guess #6: bushy
# ['dodge', 'lodge']
# Answer: felon
#
# Guess #1: fruit
# ['fable', 'false', 'fancy', 'fanny', 'fecal', 'fella', 'felon', 'femme', 'fence', 'flack', 'flake', 'flaky', 'flame', 'flank', 'flash', 'flask', 'fleck', 'flesh', 'flock', 'flood', 'floss', 'flown', 'foamy', 'focal', 'foggy', 'folly']
# Guess #2: spell
# ['false', 'felon', 'flake', 'flame']
# Guess #3: godly
# ['felon']
# Guess #4: alley
# ['felon']
# Guess #5: talon
# ['felon']
# Guess #6: glyph
# ['felon']
# Answer: crawl
#
# Guess #1: dryly
# ['brawl', 'broil', 'crawl', 'cruel', 'frail', 'grail', 'growl', 'gruel', 'prowl', 'trail', 'trawl', 'trial']
# Guess #2: shelf
'glint', 'grail', 'gruel', 'kneel', 'label', 'lager', 'lance', 'lapel', 'lapse', 'large', 'larva', 'later', 'latte', 'leant', 'leapt', 'learn', 'lease', 'least', 'leave', 'legal', 'lemur', 'leper', 'level', 'lever', 'llama', 'lumen', 'lunar', 'lunge', 'metal', 'mural', 'nasal', 'natal', 'naval', 'navel', 'panel', 'papal', 'pearl', 'penal', 'peril', 'petal', 'place', 'plain', 'plait', 'plane', 'plank', 'plant', 'plate', 'plaza', 'pleat', 'plier', 'pluck', 'plumb', 'plume', 'plump', 'plunk', 'pupil', 'quail', 'rebel', 'regal', 'renal', 'repel', 'revel', 'rural', 'trail', 'trial', 'tubal', 'ulcer', 'ultra', 'until']
# Guess #3: sedan
# ['bagel', 'bleep', 'bluer', 'camel', 'cleft', 'clerk', 'cruel', 'elect', 'excel', 'expel', 'fleck', 'fleet', 'fluke', 'flume', 'flute', 'gavel', 'gruel', 'kneel', 'label', 'lager', 'lapel', 'large', 'later', 'latte', 'plume', 'ulcer']
# Guess #4: libel
# ['cleft', 'clerk', 'elect', 'fleck', 'fluke', 'flume', 'flute', 'plume']
# Guess #5: decoy
# ['cleft', 'clerk', 'elect', 'fleck']
# Guess #6: munch
# ['elect', 'fleck']
# Answer: rearm
#
# Guess #1: build
# ['acorn', 'actor', 'afoot', 'after', 'agape', 'agate', 'agent', 'agony', 'agree', 'amass', 'amaze', 'among', 'anger', 'angry', 'angst', 'annex', 'annoy', 'aorta', 'apart', 'apnea', 'apron', 'arena', 'armor', 'aroma', 'arose', 'array', 'arrow', 'arson', 'artsy', 'ascot', 'ashen', 'askew', 'assay', 'asset', 'atone', 'avert', 'awake', 'aware', 'awash', 'awoke', 'cacao', 'cache', 'cagey', 'cameo', 'canny', 'canoe', 'canon', 'caper', 'carat', 'cargo', 'carry', 'carve', 'caste', 'catch', 'cater', 'catty', 'cease', 'chafe', 'chaff', 'champ', 'chant', 'chaos', 'charm', 'chart', 'chase', 'chasm', 'cheap', 'cheat', 'check', 'cheek', 'cheer', 'chess', 'chest', 'chock', 'choke', 'chore', 'chose', 'coach', 'coast', 'cocoa', 'comet', 'comfy', 'comma', 'conch', 'copse', 'corer', 'corny', 'coven', 'cover', 'covet', 'covey', 'cower', 'crack', 'craft', 'cramp', 'crane', 'crank', 'crash', 'crass', 'crate', 'crave', 'craze', 'crazy', 'creak', 'cream', 'creek', 'creep', 'creme', 'crepe', 'crept', 'cress', 'crest', 'croak', 'crock', 'crone', 'crony', 'crook', 'cross', 'crown', 'crypt', 'eager', 'earth', 'eaten', 'eater', 'egret', 'eject', 'emcee', 'empty', 'enact', 'enema', 'enemy', 'enjoy', 'enter', 'entry', 'envoy', 'epoch', 'epoxy', 'erase', 'erect', 'error', 'essay', 'ester', 'ether', 'ethos', 'event', 'every', 'evoke', 'exact', 'exert', 'extra', 'facet', 'fancy', 'fanny', 'farce', 'fatty', 'favor', 'feast', 'femme', 'fence', 'ferry', 'fetch', 'fever', 'fewer', 'foamy', 'foggy', 'fo
# ['cream', 'rearm']
# Guess #4: truck
# ['rearm']
# Guess #5: salsa
# ['rearm']
# Guess #6: olden
# ['rearm']
# Answer: nasal
#
# Guess #1: tabby
# ['cacao', 'cache', 'cairn', 'camel', 'cameo', 'canal', 'canoe', 'canon', 'caper', 'cargo', 'carol', 'carve', 'caulk', 'cause', 'cavil', 'dance', 'eager', 'eagle', 'easel', 'false', 'farce', 'fauna', 'favor', 'gaffe', 'gamer', 'gamma', 'gauge', 'gauze', 'gavel', 'gazer', 'halve', 'harem', 'harsh', 'haven', 'havoc', 'hazel', 'kappa', 'karma', 'laden', 'ladle', 'lager', 'lance', 'lapel', 'lapse', 'large', 'larva', 'lasso', 'laugh', 'macaw', 'macho', 'macro', 'madam', 'mafia', 'magic', 'magma', 'maize', 'major', 'maker', 'mamma', 'manga', 'mange', 'mango', 'mania', 'manic', 'manor', 'maple', 'march', 'marsh', 'mason', 'masse', 'mauve', 'maxim', 'nadir', 'naive', 'nasal', 'naval', 'navel', 'oaken', 'pagan', 'paler', 'panel', 'panic', 'papal', 'paper', 'parer', 'parka', 'parse', 'pause', 'racer', 'radar', 'radii', 'radio', 'raise', 'rajah', 'ralph', 'ramen', 'ranch', 'range', 'rapid', 'rarer', 'raven', 'razor', 'safer', 'salad', 'salon', 'salsa', 'salve', 'salvo', 'saner', 'sauce', 'sauna', 'savor', 'vague', 'valid', 'valor', 'value', 'valve', 'vapid', 'vapor', 'wafer', 'wager', 'wagon', 'waive', 'waver', 'waxen']
# Guess #2: strip
# ['cause', 'easel', 'false', 'lasso', 'mason', 'masse', 'nasal', 'pause']
# Guess #3: burly
# ['easel', 'false', 'lasso', 'nasal']
# Guess #4: shoot
# ['easel', 'false', 'nasal']
# Guess #5: munch
# ['nasal']
# Guess #6: giant
# ['nasal']
# Answer: cavil
#
# Guess #1: lumen
# ['aglow', 'alibi', 'allay', 'allot', 'allow', 'alloy', 'aloft', 'aloof', 'alpha', 'altar', 'apply', 'aptly', 'atoll', 'avail', 'axial', 'badly', 'basal', 'basil', 'billy', 'black', 'blast', 'bliss', 'blitz', 'bloat', 'block', 'blood', 'brawl', 'broil', 'bylaw', 'cabal', 'carol', 'cavil', 'chalk', 'child', 'chili', 'chill', 'civil', 'clack', 'clash', 'clasp', 'class', 'click', 'cliff', 'cloak', 'clock', 'cloth', 'color', 'coral', 'coyly', 'crawl', 'daily', 'dally', 'dilly', 'dolly', 'drawl', 'drill', 'droll', 'drool', 'dryly', 'early', 'eclat', 'elbow', 'exalt', 'extol', 'fatal', 'filly', 'filth', 'flack', 'flail', 'flair', 'flaky', 'flash', 'flask', 'flick', 'flirt', 'float', 'flock', 'flood', 'floor', 'flora', 'floss', 'focal', 'folio', 'folly', 'frail', 'frill', 'gaily', 'gayly', 'girly', 'glass', 'gloat', 'glory', 'gloss', 'glyph', 'godly', 'golly', 'grail', 'grill', 'growl', 'hilly', 'holly', 'hotly', 'icily', 'idyll', 'igloo', 'iliac', 'jolly', 'koala', 'krill', 'madly', 'milky', 'mod
# Guess #4: brake
# ['aglow', 'atoll', 'axial', 'carol', 'cavil', 'coral', 'fatal', 'focal', 'gaily', 'gayly', 'octal', 'offal', 'sally', 'salsa', 'salty', 'salvo', 'shoal', 'tally', 'total', 'villa', 'viola', 'viral', 'vital', 'vocal', 'voila', 'waltz']
# Guess #5: brash
# ['aglow', 'atoll', 'axial', 'carol', 'cavil', 'coral', 'fatal', 'focal', 'gaily', 'gayly', 'octal', 'offal', 'tally', 'total', 'villa', 'viola', 'viral', 'vital', 'vocal', 'voila', 'waltz']
# Guess #6: quell
# ['axial', 'cavil', 'fatal', 'focal', 'octal', 'offal', 'total', 'vital', 'vocal']
# Answer: imply
#
# Guess #1: belie
# ['alibi', 'alien', 'align', 'axial', 'child', 'chili', 'chill', 'click', 'cliff', 'cling', 'clink', 'daily', 'dimly', 'drill', 'field', 'final', 'flick', 'flier', 'fling', 'flint', 'flirt', 'frill', 'gaily', 'girly', 'glint', 'grill', 'guild', 'guilt', 'icily', 'ideal', 'idyll', 'iliac', 'impel', 'imply', 'krill', 'libel', 'light', 'liken', 'limbo', 'linen', 'liner', 'lingo', 'liver', 'lying', 'pixel', 'plied', 'plier', 'quill', 'quilt', 'rival', 'skill', 'slick', 'slimy', 'sling', 'slink', 'spiel', 'spill', 'spilt', 'still', 'stilt', 'swill', 'swirl', 'tidal', 'trial', 'twirl', 'vinyl', 'viola', 'viral', 'vital', 'voila', 'whirl', 'wield', 'yield']
# Guess #2: feast
# ['child', 'chili', 'chill', 'click', 'cling', 'clink', 'dimly', 'drill', 'girly', 'grill', 'guild', 'icily', 'idyll', 'imply', 'krill', 'lingo', 'lying', 'quill', 'vinyl', 'whirl']
# Guess #3: aisle
# ['child', 'chili', 'chill', 'drill', 'grill', 'guild', 'icily', 'idyll', 'imply', 'krill', 'quill']
# Guess #4: radar
# ['chili', 'chill', 'icily', 'imply', 'quill']
# Guess #5: brick
# ['imply']
# Guess #6: ideal
# ['imply']
# Answer: affix
#
# Guess #1: upper
# ...
# Guess #2: gauge
# ['dully', 'dummy', 'dumpy', 'dusky', 'dusty', 'fully', 'funky', 'funny', 'fussy', 'fuzzy', 'humid', 'humph', 'humus', 'hunky', 'husky', 'hussy', 'input', 'jumpy', 'lumpy', 'lupus', 'lusty', 'minus', 'muddy', 'mummy', 'mushy', 'musky', 'musty', 'nutty', 'puffy', 'pulpy', 'pupil', 'puppy', 'pushy', 'putty', 'quell', 'quest', 'quill', 'quilt', 'sulky', 'sully', 'sunny', 'sushi', 'tulip', 'undid', 'unfit', 'unify', 'unity', 'unlit', 'until', 'unzip']
# Guess #3: paler
# ['lupus', 'lusty', 'quell', 'quill', 'quilt', 'until']
# Guess #4: cynic
# ['quill', 'quilt']
# Guess #5: taffy
# ['quilt']
# Guess #6: skulk
# ['quilt']
# Answer: bawdy
#
# Guess #1: wreak
# ['aglow', 'allow', 'await', 'award', 'awash', 'awful', 'bawdy', 'dwarf', 'gawky', 'shawl', 'spawn', 'swami', 'swamp', 'swarm', 'swash', 'swath', 'tawny', 'twang']
# Guess #2: angle
# ['bawdy', 'swami', 'swamp', 'swash', 'swath']
# Guess #3: gavel
# ['bawdy']
# Guess #4: fugue
# ['bawdy']
# Guess #5: quiet
# ['bawdy']
# Guess #6: beret
# ['bawdy']
# Answer: tarot
#
# Guess #1: creak
# ['abhor', 'abort', 'acorn', 'acrid', 'actor', 'adorn', 'after', 'aider', 'alarm', 'alter', 'amber', 'anger', 'angry', 'aorta', 'apart', 'apron', 'augur', 'award', 'baler', 'baron', 'beard', 'board', 'dairy', 'diary', 'dwarf', 'fairy', 'favor', 'flair', 'flora', 'gamer', 'gayer', 'gazer', 'guard', 'hairy', 'hardy', 'harem', 'harpy', 'harry', 'harsh', 'hater', 'heard', 'heart', 'hoard', 'labor', 'lager', 'larva', 'later', 'layer', 'learn', 'major', 'manor', 'march', 'marry', 'marsh', 'mayor', 'nadir', 'ovary', 'paler', 'paper', 'parer', 'parka', 'parry', 'party', 'payer', 'pearl', 'quart', 'rabbi', 'rabid', 'radii', 'radio', 'rainy', 'rally', 'ralph', 'ramen', 'ranch', 'randy', 'rapid', 'rarer', 'raspy', 'ratio', 'ratty', 'raven', 'rayon', 'razor', 'reach', 'react', 'ready', 'realm', 'rearm', 'roach', 'roast', 'rumba', 'safer', 'saner', 'satyr', 'savor', 'scarf', 'scary', 'shard', 'sharp', 'smart', 'snarl', 'stair', 'start', 'swarm', 'tamer', 'taper', 'tapir', 'tardy', 'tarot', 'teary', 'terra', 'tiara', 'ultra', 'umbra', 'valor', 'vapor', 'wafer', 'wager', 'warty', 'water', 'waver', 'weary', 'wharf', 'yearn', 'zebra']
# Guess #2: plant
# ['abort', 'tarot']
# Guess #3: curio
# ['tarot']
# Guess #4: learn
# ['tarot']
# Guess #5: chant
# ['tarot']
# Guess #6: eager
# ['tarot']
# Answer: viola
#
# Guess #1: octal
# ['aglow', 'allot', 'allow', 'alloy', 'aloft', 'alone', 'along', 'aloof', 'aloud', 'flora', 'koala', 'labor', 'lasso', 'loamy', 'loath', 'polka', 'salon', 'salvo', 'talon', 'valor', 'viola', 'voila']
# Guess #2: glean
# ['aglow', 'koala', 'labor', 'lasso', 'loamy', 'loath', 'polka', 'salvo', 'valor', 'viola', 'voila']
# Guess #3: spool
# ['viola']
# Guess #4: crazy
# ['viola']
# Guess #5: inane
# ['viola']
# Guess #6: cubic
# ['viola']
# Answer: medal
#
# Guess #1: fella
# ['decal', 'leach', 'leafy', 'leaky', 'leant', 'leapt', 'learn', 'lease', 'leash', 'least', 'leave', 'legal', 'medal', 'metal', 'pearl', 'pedal', 'penal', 'petal', 'regal', 'renal']
# Guess #2: sonic
# ['leaky', 'leapt', 'leave', 'legal', 'medal', 'metal', 'pearl', 'pedal', 'petal', 'regal']
# Guess #3: birch
# ['leaky', 'leapt', 'leave', 'legal', 'medal', 'metal', 'pedal', 'petal']
# Guess #4: fetch
# ['leaky', 'leave', 'legal', 'medal', 'pedal']
# Guess #5: ramen
# ['medal']
# Guess #6: video
# ['medal']
# Answer: maker
#
# Guess #1: owner
# ['after', 'aider', 'alter', 'amber', 'baker', 'baler', 'bluer', 'buyer', 'caper', 'cater', 'cheer', 'cider', 'crier', 'cyber', 'defer', 'deter', 'diver', 'drier', 'dryer', 'eager', 'eater', 'elder', 'ember', 'ester', 'ether', 'fever', 'fiber', 'filer', 'fixer', 'flier', 'flyer', 'freer', 'gamer', 'gayer', 'gazer', 'giver', 'hater', 'hyper', 'idler', 'lager', 'later', 'layer', 'leper', 'lever', 'liver', 'maker', 'meter', 'miser', 'paler', 'paper', 'parer', 'payer', 'piper', 'plier', 'purer', 'queer', 'racer', 'rarer', 'refer', 'rider', 'riper', 'riser', 'river', 'ruder', 'ruler', 'safer', 'sever', 'sheer', 'skier', 'steer', 'super', 'surer', 'taker', 'tamer', 'taper', 'tiger', 'timer', 'truer', 'tuber', 'udder', 'ulcer', 'upper', 'usher', 'utter', 'viper']
# Guess #2: blimp
# ['gamer', 'maker', 'meter', 'tamer']
# Guess #3: climb
# ['gamer', 'maker', 'meter', 'tamer']
# Guess #4: jelly
# ['gamer', 'maker', 'tamer']
# Guess #5: north
# ['gamer', 'maker']
# Guess #6: slang
# ['maker']
# Answer: corny
#
# Guess #1: olive
# ['abbot', 'abhor', 'abort', 'about', 'acorn', 'actor', 'adopt', 'adorn', 'afoot', 'agony', 'among', 'annoy', 'aorta', 'apron', 'arbor', 'ardor', 'armor', 'aroma', 'arrow', 'arson', 'ascot', 'bacon', 'banjo', 'baron', 'baton', 'bayou', 'board', 'boast', 'bobby', 'bongo', 'bonus', 'booby', 'boost', 'booth', 'booty', 'boozy', 'borax', 'bosom', 'bossy', 'botch', 'bough', 'bound', 'broad', 'brood', 'brook', 'broom', 'broth', 'brown', 'buxom', 'cacao', 'canon', 'cargo', 'chaos', 'chock', 'chord', 'coach', 'coast', 'cobra', 'cocoa', 'comfy', 'comma', 'conch', 'condo', 'corny', 'couch', 'cough', 'count', 'court', 'croak', 'crock', 'crony', 'crook', 'cross', 'croup', 'crowd', 'crown', 'dodgy', 'dogma', 'donor', 'donut', 'doubt', 'dough', 'dowdy', 'downy', 'dowry', 'droop', 'dross', 'drown', 'ebony', 'endow', 'enjoy', 'epoch', 'epoxy', 'error', 'ethos', 'fjord', 'foamy', 'focus', 'foggy', 'foray', 'forgo', 'forth', 'forty', 'forum', 'found', 'frock', 'frond', 'front', 'frost', 'froth', 'frown', 'furor', 'ghost', 'gonad', 'goody', 'goofy', 'gourd', 'groan', 'groom', 'gross', 'group', 'grout', 'grown', 'gumbo', 'gusto', 'hoard', 'hobby', 'honor', 'horny', 'hound', 'howdy', 'humor', 'hydro', 'inbox', 'ingot', 'intro', 'irony', 'joust', 'jumbo', 'junto', 'juror', 'knock', 'known', 'labor', 'lasso', 'loamy', 'loath', 'lobby', 'locus', 'lofty', 'loopy', 'lorry', 'lousy', 'macho', 'macro', 'major', 'mambo', 'mango', 'manor', 'mason', 'mayor', 'mocha', 'month', 'moody', 'moron', 'morph', 'mossy', 'motor', 'motto', 'mound', 'mount', 'mourn', 'mouth', 'nomad', 'north', 'notch', 'phony', 'photo', 'podgy', 'pooch', 'poppy', 'porch', 'pouch', 'pound', 'pouty', 'prong', 'proof', 'proud', 'proxy', 'quota', 'quoth', 'rayon', 'razor', 'roach', 'roast', 'robot', 'rocky', 'roomy', 'roost', 'rotor', 'rough', 'round', 'rowdy', 'rumor', 'scoff', 'scoop', 'scorn', 'scour', 'scout', 'shock', 'shook', 'shoot', 'shorn', 'short', 'shout', 'shown', 'showy', 'smock', 'smoky', 'snoop', 'snort', 'snout', 'snowy', 'soapy', 'soggy', 'sonar', 'sooth', 'sooty', 'sorry', 'sound', 'south', 'spoof', 'spook', 'spoon', 'sport', 'spout', 'stock', 'stomp', 'stony', 'stood', 'stoop', 'stork', 'storm', 'story', 'stout', 'swoon', 'swoop', 'sword', 'sworn', 'synod', 'taboo', 'tango', 'tarot', 'thong', 'thorn', 'throb', 'throw', 'toast', 'today', 'toddy', 'tonga', 'tooth', 'topaz', 'torch', 'torso', 'torus', 'touch', 'tough', 'troop', 'trout', 'tumor', 'turbo', 'tutor', 'vapor', 'vodka', 'vouch', 'wagon', 'whoop', 'woman', 'woody', 'woozy', 'wordy', 'worry', 'worst', 'worth', 'wound', 'wrong', 'young', 'youth']
# Guess #2: gloom
# ['aorta', 'banjo', 'board', 'boast', 'bobby', 'bongo', 'bonus', 'borax', 'bossy', 'botch', 'bough', 'bound', 'cacao', 'cargo', 'coach', 'coast', 'cobra', 'comfy', 'comma', 'conch', 'condo', 'corny', 'couch', 'cough', 'count', 'court', 'dodgy', 'dogma', 'donut', 'doubt', 'dough', 'dowdy', 'downy', 'dowry', 'foamy', 'focus', 'foggy', 'foray', 'forgo', 'forth', 'forty', 'found', 'hoard', 'hobby', 'horny', 'hound', 'howdy', 'hydro', 'joust', 'jumbo', 'junto', 'nomad', 'north', 'notch', 'podgy', 'poppy', 'porch', 'pouch', 'pound', 'pouty', 'roach', 'roast', 'rocky', 'rough', 'round', 'rowdy', 'soapy', 'soggy', 'sonar', 'sorry', 'sound', 'south', 'tango', 'toast', 'today', 'toddy', 'tonga', 'topaz', 'torch', 'torso', 'torus', 'touch', 'tough', 'turbo', 'woman', 'wordy', 'worry', 'worst', 'worth', 'wound', 'youth']
# Guess #3: arise
# ['corny', 'court', 'dowry', 'forth', 'forty', 'horny', 'hydro', 'north', 'porch', 'rocky', 'round', 'rowdy', 'torch', 'turbo', 'wordy', 'worry', 'worth']
# Guess #4: golem
# ['corny', 'court', 'dowry', 'forth', 'forty', 'horny', 'north', 'porch', 'rocky', 'round', 'rowdy', 'torch', 'wordy', 'worry', 'worth']
# Guess #5: store
# ['corny', 'forth', 'forty', 'horny', 'north', 'porch', 'rocky', 'round', 'rowdy', 'wordy', 'worth']
# Guess #6: balmy
# ['corny', 'horny', 'rocky', 'rowdy', 'wordy']
# Answer: bitty
#
# Guess #1: modal
shirt', 'shrew', 'shrub', 'shrug', 'shuck', 'shunt', 'shush', 'siege', 'sieve', 'sight', 'since', 'sinew', 'singe', 'siren', 'sissy', 'sixth', 'sixty', 'skier', 'skiff', 'skirt', 'skunk', 'sneer', 'sniff', 'snipe', 'snuck', 'snuff', 'speck', 'spent', 'spice', 'spicy', 'spike', 'spiky', 'spine', 'spiny', 'spire', 'spite', 'spree', 'sprig', 'spunk', 'spurn', 'spurt', 'squib', 'steep', 'steer', 'stein', 'stern', 'stick', 'stiff', 'sting', 'stink', 'stint', 'strip', 'strut', 'stuck', 'stuff', 'stung', 'stunk', 'stunt', 'suing', 'suite', 'sunny', 'super', 'surer', 'surge', 'sushi', 'sweep', 'sweet', 'swept', 'swift', 'swine', 'swing', 'swish', 'swung', 'syrup', 'teeth', 'tenet', 'tense', 'tenth', 'tepee', 'terse', 'testy', 'theft', 'their', 'there', 'these', 'thick', 'thief', 'thigh', 'thing', 'think', 'three', 'threw', 'tiger', 'tight', 'tipsy', 'tithe', 'tribe', 'trice', 'trick', 'tripe', 'trite', 'truce', 'truck', 'truer', 'trunk', 'truss', 'trust', 'truth', 'tryst', 'tuber', 'tunic', 'tweet', 'twice', 'twine', 'twist', 'twixt', 'tying', 'uncut', 'unfit', 'unify', 'unite', 'unity', 'unset', 'untie', 'unzip', 'upper', 'upset', 'urine', 'usher', 'using', 'usurp', 'utter', 'venue', 'verge', 'verse', 'verve', 'viper', 'virus', 'visit', 'vixen', 'vying', 'weigh', 'where', 'which', 'whiff', 'whine', 'whiny', 'whisk', 'white', 'wight', 'wince', 'winch', 'wiser', 'wispy', 'witch', 'witty', 'wreck', 'wrest', 'wring', 'wrist', 'write', 'wr ...
# Guess #2: allow
# ['beech', 'beefy', 'befit', 'beget', 'begin', 'begun', 'being', 'bench', 'beret', 'berry', 'berth', 'beset', 'bicep', 'binge', 'birch', 'birth', 'bitty', 'bribe', 'brick', 'brief', 'brine', 'bring', 'brink', 'briny', 'brisk', 'brunt', 'brush', 'brute', 'buggy', 'bunch', 'bunny', 'burnt', 'burst', 'bushy', 'butch', 'butte', 'buyer', 'check', 'cheek', 'cheer', 'chess', 'chest', 'chick', 'chief', 'chirp', 'chuck', 'chunk', 'churn', 'chute', 'cinch', 'civic', 'creek', 'creep', 'crepe', 'crept', 'cress', 'crest', 'crick', 'crier', 'crisp', 'crush', 'crust', 'crypt', 'cubic', 'curry', 'curse', 'curve', 'curvy', 'cutie', 'cyber', 'cynic', 'eerie', 'egret', 'eight', 'eject', 'eking', 'ennui', 'ensue', 'enter', 'entry', 'equip', 'erect', 'erupt', 'ester', 'ether', 'ethic', 'event', 'every', 'evict', 'exert', 'exist', 'eying', 'feign', 'fence', 'ferry', 'fetch', 'fetus', 'fever', 'fiber', 'ficus', 'fiery', 'fifth', 'fifty', 'fight', 'finch', 'finer', 'first', 'fishy', 'fixer', 'fizzy', 'freer', 'fresh', 'frisk', 'fritz', 'fruit', 'fugue', 'fungi', 'funky', 'funny', 'furry', '